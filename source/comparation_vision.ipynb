# %%
import pandas as pd
import os
import numpy as np

import anthropic
from openai import OpenAI

import base64
import httpx
import requests
import json
import time

from dotenv import load_dotenv, find_dotenv
from IPython.display import Image,display

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 500)

BLUE = '\033[94m'
END = '\033[0m' 

load_dotenv(find_dotenv())
# Out:
# True

# %%
openai_client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
claude_client = anthropic.Anthropic(api_key=os.environ["CLAUDE_KEY"])

# %%
image_url_1 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/Red_square_Moscow_cityscape_%288309148721%29.jpg/1200px-Red_square_Moscow_cityscape_%288309148721%29.jpg'
image_url_2 = 'https://images.squarespace-cdn.com/content/v1/5b3fc87b45776e887e966e82/ea4b3853-7558-4048-8051-d986e71ec39d/beagle-on-meadow-2021-08-26-15-58-22-utc.jpg'

# %%
prompt_1 = '''
        CONTEXT:
        For the given place on the image provide me with historical background information about the location,
        main attractions of interest at the location and outline the pricing information for visiting the location.
        Do not include disclaimer.
        Descriptions should have a dry tone.
        
        OUTPUT:
        After determining historical background, main attractions, and pricing information output them in JSON format. 
        For example:
        [
        {{ historical background : ['historical fact 1', 
                                    'historical fact 2', 
                                     ..., 
                                    'historical fact n'],
        main attractions : ['main attractions 1', 
                            'main attractions 2', 
                             ..., 
                            'main attractions n'],
        pricing :['pricing for 1', 
                  'pricing for 2', 
                   ..., 
                   'pricing for n']
        }}
        ] 

        '''


prompt_2 = '''
        CONTEXT:
        For the givem image of the animal provide me animal name and give a brief overview of the animal, including its species, habitat, behaviors, and any interesting facts
        Do not include disclaimer.
        Descriptions should have a dry tone.
        
        OUTPUT:
        After determining animal name and brief overview of the animal output them in JSON format. 
        For example:
        [
        {{ 'animal name' : ['animal name'],
        'overview' : ['overview 1', 
                      'overview 2', 
                       ..., 
                      'overview n'],
        }}
        ] 

        '''

# %%
def gpt_description(image_url, prompt):
    response = openai_client.chat.completions.create(
      model="gpt-4-vision-preview",
      messages=[
        {
          "role": "user",
          "content": [
            {
              "type": "text",
              "text": prompt
            },
            {
              "type": "image_url",
              "image_url": {
                  "url": image_url,
                  "detail": "low"
              }
            }
          ]
        }
      ],
      temperature=0,
      max_tokens=2500,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )
    return response


def opus_description(image_url, prompt):    
    image_media_type = "image/jpeg"
    image_data = base64.b64encode(httpx.get(image_url).content).decode("utf-8")
    
    response = claude_client.messages.create(
      model="claude-3-opus-20240229",
      messages=[
        {
          "role": "user",
          "content": [
            {
            "type": "image",
                  "source": {
                      "type": "base64",
                      "media_type": image_media_type,
                      "data": image_data,
                  },
            },
            {
              "type": "text",
              "text": prompt
            }
              ],
            }
          ],
      temperature=0,
      max_tokens=2500,
      top_p=1,
    )
    return response


def sonnet_description(image_url, prompt):
    image_media_type = "image/jpeg"
    image_data = base64.b64encode(httpx.get(image_url).content).decode("utf-8")
    
    response = claude_client.messages.create(
      model="claude-3-sonnet-20240229",
      messages=[
        {
          "role": "user",
          "content": [
            {
            "type": "image",
                  "source": {
                      "type": "base64",
                      "media_type": image_media_type,
                      "data": image_data,
                  },
            },
            {
              "type": "text",
              "text": prompt
            }
              ],
            }
          ],
      temperature=0,
      max_tokens=2500,
      top_p=1,
    )
    return response



def haiku_description(image_url, prompt):
    image_media_type = "image/jpeg"
    image_data = base64.b64encode(httpx.get(image_url).content).decode("utf-8")
    
    response = claude_client.messages.create(
      model="claude-3-haiku-20240307",
      messages=[
        {
          "role": "user",
          "content": [
            {
            "type": "image",
                  "source": {
                      "type": "base64",
                      "media_type": image_media_type,
                      "data": image_data,
                  },
            },
            {
              "type": "text",
              "text": prompt
            }
              ],
            }
          ],
      temperature=0,
      max_tokens=2500,
      top_p=1,
    )
    return response

# %%
def cost_gpt(total, prompt_tokens, completion_tokens):
    return (((total * prompt_tokens)/1000000) * 10) + (((total * completion_tokens)/1000000) * 30)

def cost_opus(total, input_token, output_token):
  return(((total * input_token)/1000000) * 15) + (((total * output_token)/1000000) * 75)

def cost_sonnet(total, input_token, output_token):
  return(((total * input_token)/1000000) * 3) + (((total * output_token)/1000000) * 15)

def cost_haiku(total, input_token, output_token):
  return(((total * input_token)/1000000) * 0.25) + (((total * output_token)/1000000) * 1.25)

# %%
display(Image(url=image_url_1,width=450))

print('\n')
print(BLUE + 'GPT-4-1106-preview' + END, '\n')
st = time.time()
result_gpt = gpt_description(image_url_1, prompt_1)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_gpt.usage.prompt_tokens)
print('Number of output tokens:', result_gpt.usage.completion_tokens, '\n')
print('Cost for 200k images: ', f'${cost_gpt(100000,result_gpt.usage.prompt_tokens,result_gpt.usage.completion_tokens)} $')
print('Cost per image: ', f'${cost_gpt(1,result_gpt.usage.prompt_tokens,result_gpt.usage.completion_tokens)} $','\n')
for l in result_gpt.choices[0].message.content.split('\n'):
        print(l)


print('\n')
print(BLUE + 'Opus' + END, '\n')
st = time.time()
result_opus = opus_description(image_url_1, prompt_1)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_opus.usage.input_tokens)
print('Number of output tokens:', result_opus.usage.output_tokens, '\n')
print('Cost for 200k images: 'f'{cost_opus(100000,result_opus.usage.input_tokens,result_opus.usage.output_tokens)} $')
print('Cost per image: ', f'{cost_opus(1,result_opus.usage.input_tokens,result_opus.usage.output_tokens)} $','\n')
for l in result_opus.content[0].text.split('\n'):
        print(l)


print('\n')
print(BLUE + 'Sonnet' + END, '\n')
st = time.time()
result_sonnet = sonnet_description(image_url_1, prompt_1)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_sonnet.usage.input_tokens)
print('Number of output tokens:', result_sonnet.usage.output_tokens, '\n')
print('Cost for 200k images: 'f'{cost_sonnet(100000,result_sonnet.usage.input_tokens,result_sonnet.usage.output_tokens)} $')
print('Cost per image: ', f'{cost_sonnet(1,result_sonnet.usage.input_tokens,result_sonnet.usage.output_tokens)} $','\n')
for l in result_sonnet.content[0].text.split('\n'):
        print(l)



print('\n')
print(BLUE + 'Haiku' + END, '\n')
st = time.time()
result_haiku = haiku_description(image_url_1, prompt_1)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_haiku.usage.input_tokens)
print('Number of output tokens:', result_haiku.usage.output_tokens, '\n')
print('Cost for 200k images: 'f'{cost_haiku(100000,result_haiku.usage.input_tokens,result_haiku.usage.output_tokens)} $')
print('Cost per image: ', f'{cost_haiku(1,result_haiku.usage.input_tokens,result_haiku.usage.output_tokens)} $','\n')
for l in result_haiku.content[0].text.split('\n'):
        print(l)
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/13/Red_square_Moscow_cityscape_%288309148721%29.jpg/1200px-Red_square_Moscow_cityscape_%288309148721%29.jpg" width="450"/>
# GPT-4-1106-preview
#
# Time:  25.02 seconds
#
# Number of input tokens: 269
# Number of output tokens: 354
#
# Cost for 200k images:  $1331.0 $
# Cost per image:  $0.013309999999999999 $
#
# [
#     {
#         "historical background": [
#             "The image shows Red Square in Moscow, which has been a central place in Russian history since the 15th century.",
#             "It is surrounded by significant buildings, including the Kremlin, St. Basil's Cathedral, the State Historical Museum, and the GUM department store.",
#             "Red Square has been the site of numerous important events in Russian history, including coronations, parades, and political demonstrations."
#         ],
#         "main attractions": [
#             "St. Basil's Cathedral, known for its colorful, onion-shaped domes and its position as a symbol of Russian architecture.",
#             "The Kremlin, a historic fortified complex that includes palaces, cathedrals, and the official residence of the President of Russia.",
#             "The State Historical Museum, which showcases Russian history from ancient times to the present day.",
#             "Lenin's Mausoleum, where the embalmed body of Vladimir Lenin, the founder of the Soviet Union, is on display.",
#             "GUM department store, a historic shopping arcade with high-end shops and eateries."
#         ],
#         "pricing": [
#             "Entrance to Red Square is generally free.",
#             "St. Basil's Cathedral: Admission fee required, varies by age and group size, with discounts for students and children.",
#             "The Kremlin: Admission fee required, with separate tickets for the Armory Chamber and the Diamond Fund.",
#             "State Historical Museum: Admission fee required, with discounts for students and children.",
#             "Lenin's Mausoleum: Free, but may have long lines and limited visiting hours.",
#             "GUM department store: Free entry, prices for goods and services vary."
#         ]
#     }
# ]
#
#
# Opus
#
# Time:  25.21 seconds
#
# Number of input tokens: 1541
# Number of output tokens: 363
#
# Cost for 200k images: 5034.0 $
# Cost per image:  0.050339999999999996 $
#
# [
# {
# historical background : ['The image depicts Red Square, a historic city square in Moscow, Russia',
#                          'Red Square separates the Kremlin, the former royal citadel and now the official residence of the President of Russia, from a historic merchant quarter known as Kitai-gorod',
#                          'Red Square is often considered to be the central square of Moscow and all of Russia',
#                          'The square's name has nothing to do with communism or the red bricks around the square, but derives from the old Russian word "krasnyi", which meant "beautiful"'],
# main attractions : ['Saint Basil\'s Cathedral with its colorful onion domes, a famous Russian Orthodox church and now a museum on the southern side of Red Square',
#                     'The Kremlin, a fortified complex with several cathedrals and palaces, the official residence of the President of Russia',
#                     'The Spasskaya Tower, the main tower with a famous clock on the eastern wall of the Kremlin',
#                     'The GUM Department Store, a famous shopping mall on the eastern side of Red Square',
#                     'The State Historical Museum on the northern side of Red Square'],
# pricing : ['Admission to Red Square is free',
#            'Tickets to Saint Basil\'s Cathedral cost 700 rubles for adults, 400 rubles for students',
#            'Admission to the Kremlin museums (Armoury, Diamond Fund Exhibition) starts from 500 rubles',
#            'GUM Department Store has free admission, individual store prices vary']
# }
# ]
#
#
# Sonnet
#
# Time:  12.44 seconds
#
# Number of input tokens: 1500
# Number of output tokens: 480
#
# Cost for 200k images: 1170.0 $
# Cost per image:  0.0117 $
#
# [
# {
#   "historical background": [
#     "The image depicts the Red Square in Moscow, Russia, which has been the heart of the city since the 15th century.",
#     "The St. Basil's Cathedral, with its iconic colorful onion domes, was built in the 16th century to commemorate the capture of Kazan and Astrakhan.",
#     "The Kremlin, the fortified complex seen in the background, has been the official residence of the Russian president and the center of Russian political power since the 14th century."
#   ],
#   "main attractions": [
#     "St. Basil's Cathedral, a UNESCO World Heritage Site and one of the most recognizable landmarks in Russia.",
#     "The Kremlin, a fortified complex that houses several cathedrals, palaces, and museums, including the Armoury Chamber and the Diamond Fund.",
#     "Lenin's Mausoleum, where the embalmed body of Vladimir Lenin, the founder of the Soviet Union, is on display.",
#     "The State Historical Museum, which showcases Russian history and culture.",
#     "GUM, a historic shopping mall located on the eastern side of Red Square."
#   ],
#   "pricing": [
#     "Entry to Red Square is free.",
#     "Admission to St. Basil's Cathedral costs around 700 rubles (approximately $10 USD) for adults and 300 rubles (approximately $4 USD) for children.",
#     "Admission to the Kremlin Grounds and Cathedrals costs around 1000 rubles (approximately $15 USD) for adults and 500 rubles (approximately $7 USD) for children.",
#     "Admission to the Armoury Chamber costs around 1000 rubles (approximately $15 USD) for adults and 500 rubles (approximately $7 USD) for children.",
#     "Admission to the State Historical Museum costs around 500 rubles (approximately $7 USD) for adults and 250 rubles (approximately $3.50 USD) for children."
#   ]
# }
# ]
#
#
# Haiku
#
# Time:  7.57 seconds
#
# Number of input tokens: 1546
# Number of output tokens: 450
#
# Cost for 200k images: 94.9 $
# Cost per image:  0.000949 $
#
# The location depicted in the image is the Red Square in Moscow, Russia. Here is the information about the historical background, main attractions, and pricing:
#
# [
# {
# historical background: [
# "The Red Square is the central square of Moscow, located in the heart of the city. It has been the site of many significant historical events in Russian history, including military parades, coronations, and political demonstrations.",
# "The square is surrounded by some of the most iconic landmarks of Moscow, including the Kremlin, St. Basil's Cathedral, and the State Historical Museum.",
# "The name 'Red Square' is derived from the Russian word 'krasnaya,' which can mean both 'red' and 'beautiful.' The square has been the center of Moscow's political and cultural life for centuries."
# ],
# main attractions: [
# "The Kremlin, the official residence of the President of Russia, is a UNESCO World Heritage Site and one of the most famous landmarks in Moscow.",
# "St. Basil's Cathedral, with its colorful, onion-shaped domes, is a renowned symbol of Russia and a must-see attraction in the Red Square.",
# "The State Historical Museum, located on the eastern side of the Red Square, houses a vast collection of artifacts and exhibits chronicling the history of Russia.",
# "The Lenin Mausoleum, where the embalmed body of Vladimir Lenin is on display, is a significant historical site within the Red Square."
# ],
# pricing: [
# "Admission to the Red Square is free and open to the public.",
# "Entrance to the Kremlin and its cathedrals requires a paid ticket, with prices ranging from 500 to 1,000 rubles (approximately $7 to $14 USD) for adults.",
# "Tickets to the State Historical Museum start at 400 rubles (approximately $6 USD) for adults.",
# "The Lenin Mausoleum has a nominal admission fee of 100 rubles (approximately $1.50 USD) for adults."
# }
# ]

# %%
display(Image(url=image_url_2,width=450))

print('\n')
print(BLUE + 'GPT-4-1106-preview' + END, '\n')
st = time.time()
result_gpt = gpt_description(image_url_2, prompt_2)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_gpt.usage.prompt_tokens)
print('Number of output tokens:', result_gpt.usage.completion_tokens, '\n')
print('Cost for 200k images: ', f'${cost_gpt(100000,result_gpt.usage.prompt_tokens,result_gpt.usage.completion_tokens)} $')
print('Cost per image: ', f'${cost_gpt(1,result_gpt.usage.prompt_tokens,result_gpt.usage.completion_tokens)} $','\n')
for l in result_gpt.choices[0].message.content.split('\n'):
        print(l)


print('\n')
print(BLUE + 'Opus' + END, '\n')
st = time.time()
result_opus = opus_description(image_url_2, prompt_2)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_opus.usage.input_tokens)
print('Number of output tokens:', result_opus.usage.output_tokens, '\n')
print('Cost for 200k images: 'f'{cost_opus(100000,result_opus.usage.input_tokens,result_opus.usage.output_tokens)} $')
print('Cost per image: ', f'{cost_opus(1,result_opus.usage.input_tokens,result_opus.usage.output_tokens)} $','\n')
for l in result_opus.content[0].text.split('\n'):
        print(l)


print('\n')
print(BLUE + 'Sonnet' + END, '\n')
st = time.time()
result_sonnet = sonnet_description(image_url_2, prompt_2)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_sonnet.usage.input_tokens)
print('Number of output tokens:', result_sonnet.usage.output_tokens, '\n')
print('Cost for 200k images: 'f'{cost_sonnet(100000,result_sonnet.usage.input_tokens,result_sonnet.usage.output_tokens)} $')
print('Cost per image: ', f'{cost_sonnet(1,result_sonnet.usage.input_tokens,result_sonnet.usage.output_tokens)} $','\n')
for l in result_sonnet.content[0].text.split('\n'):
        print(l)



print('\n')
print(BLUE + 'Haiku' + END, '\n')
st = time.time()
result_haiku = haiku_description(image_url_2, prompt_2)
print('Time: ', round(time.time()-st, 2),'seconds','\n')
print('Number of input tokens:', result_haiku.usage.input_tokens)
print('Number of output tokens:', result_haiku.usage.output_tokens, '\n')
print('Cost for 200k images: 'f'{cost_haiku(100000,result_haiku.usage.input_tokens,result_haiku.usage.output_tokens)} $')
print('Cost per image: ', f'{cost_haiku(1,result_haiku.usage.input_tokens,result_haiku.usage.output_tokens)} $','\n')
for l in result_haiku.content[0].text.split('\n'):
        print(l)
# Out:
# <img src="https://images.squarespace-cdn.com/content/v1/5b3fc87b45776e887e966e82/ea4b3853-7558-4048-8051-d986e71ec39d/beagle-on-meadow-2021-08-26-15-58-22-utc.jpg" width="450"/>
# GPT-4-1106-preview
#
# Time:  9.72 seconds
#
# Number of input tokens: 218
# Number of output tokens: 165
#
# Cost for 200k images:  $713.0 $
# Cost per image:  $0.007129999999999999 $
#
# [
# {
# "animal name": ["Beagle"],
# "overview": [
# "The Beagle is a breed of small hound that is similar in appearance to the much larger foxhound.",
# "Beagles are scent hounds, developed primarily for tracking hare, rabbit, and other game.",
# "They are known for their keen sense of smell and tracking instinct.",
# "Beagles are intelligent, and are popular as pets because of their size, even temper, and lack of inherited health problems.",
# "These dogs are also used as detection dogs in quarantine around the world due to their acute sense of smell.",
# "Beagles are active companions for kids and adults alike.",
# "Their habitats include temperate climates and domestic settings.",
# "Beagles were originally bred for hunting purposes and have a strong instinct to follow scents."
# ]
# }
# ]
#
#
# Opus
#
# Time:  17.22 seconds
#
# Number of input tokens: 1794
# Number of output tokens: 205
#
# Cost for 200k images: 4228.5 $
# Cost per image:  0.042285 $
#
# [
# {
# 'animal name': ['Beagle'],
# 'overview': ['The Beagle is a breed of small scent hound, similar in appearance to the much larger foxhound.',
#              'The Beagle is a popular pet due to its size, good temper, and lack of inherited health problems.',
#              'Beagles have an excellent sense of smell and have been employed as detection dogs for prohibited agricultural imports and foodstuffs in quarantine around the world.',
#              'The modern breed was developed in Great Britain around the 1830s from several breeds, including the Talbot Hound, the North Country Beagle, the Southern Hound, and possibly the Harrier.',
#              'Beagles are intelligent but single-minded. They are bred for the long chase and are oblivious to commands when they have picked up a scent.']
# }
# ]
#
#
# Sonnet
#
# Time:  9.18 seconds
#
# Number of input tokens: 1753
# Number of output tokens: 172
#
# Cost for 200k images: 783.9000000000001 $
# Cost per image:  0.007839 $
#
# [
#   {
#     'animal name': ['Beagle'],
#     'overview': [
#       'The animal in the image is a Beagle, a breed of small scent hound that was originally bred for hunting hares.',
#       'Beagles are known for their compact size, short fur, and distinctive tri-color coat pattern of black, white, and tan.',
#       'They have a keen sense of smell and are often used for tracking and detection purposes.',
#       'Beagles are friendly, intelligent, and energetic dogs that make great family pets, but they require regular exercise and mental stimulation.',
#       'They are pack animals and thrive on companionship, making them excellent companions for active households.'
#     ]
#   }
# ]
#
#
# Haiku
#
# Time:  5.31 seconds
#
# Number of input tokens: 1799
# Number of output tokens: 174
#
# Cost for 200k images: 66.725 $
# Cost per image:  0.00066725 $
#
# [
# {
# 'animal name' : ['Beagle'],
# 'overview' : ['The Beagle is a small, compact breed of dog that was originally developed in the United Kingdom for hunting hares. They are known for their keen sense of smell and their friendly, curious nature. Beagles typically stand around 13-15 inches tall at the shoulder and weigh between 20-30 pounds. They have a short, smooth coat that can come in a variety of colors including tri-color, lemon, and red and white. Beagles are often used as scent hounds and are popular as both hunting and companion dogs. They are known for their energetic and playful personalities, and their small size makes them well-suited for apartment living.']
# }
# ]
